# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns',None)
pd.set_option('display.max_columns',None)
pd.set_option('display.max_colwidth',None)

# %%
df = pd.read_csv("https://media.geeksforgeeks.org/wp-content/uploads/nba.csv")
df["FirstName"]= df["Name"].str.split(" ", n = 1, expand = True)[0]
df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary FirstName
# 0              Texas  7730337.0     Avery
# 1          Marquette  6796117.0       Jae
# 2  Boston University        NaN      John
# 3      Georgia State  1148640.0      R.J.
# 4                NaN  5000000.0     Jonas

# %%
df=pd.DataFrame(data=[[500,'a'],['$1,000.00','a'],['300.1','a'],['$750.01','a'],['300','a'],['250','a']],columns=['Sales','Customer'])
df['Sales_Type'] = df['Sales'].apply(lambda x: type(x).__name__)
df['Sales'].apply(type).value_counts()
df['Sales'].apply(clean_currency).astype('float')
df['Sales'].apply(lambda x: x.replace('$', '').replace(',', '') if isinstance(x, str) else x).astype(float)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-efea46102196> in <module>()
#       2 df['Sales_Type'] = df['Sales'].apply(lambda x: type(x).__name__)
#       3 df['Sales'].apply(type).value_counts()
# ----> 4 df['Sales'].apply(clean_currency).astype('float')
#       5 df['Sales'].apply(lambda x: x.replace('$', '').replace(',', '') if isinstance(x, str) else x).astype(float)
#
# NameError: name 'clean_currency' is not defined

# %%
def clean_currency(x):
    """ If the value is a string, then remove currency symbol and delimiters
    otherwise, the value is numeric and can be converted
    """
    if isinstance(x, str):
        return(x.replace('$', '').replace(',', ''))
    return(x)

# %%
df = pd.DataFrame({"A": ["foo", "foo", "foo", "foo", "foo",
                         "bar", "bar", "bar", "bar"],
                   "B": ["one", "one", "one", "two", "two",
                         "one", "one", "two", "two"],
                   "C": ["small", "large", "large", "small",
                         "small", "large", "small", "small",
                         "large"],
                   "D": [1, 2, 2, 3, 3, 4, 5, 6, 7],
                   "E": [2, 4, 5, 5, 6, 6, 8, 9, 9]})
df
# Out:
#      A    B      C  D  E
# 0  foo  one  small  1  2
# 1  foo  one  large  2  4
# 2  foo  one  large  2  5
# 3  foo  two  small  3  5
# 4  foo  two  small  3  6
# 5  bar  one  large  4  6
# 6  bar  one  small  5  8
# 7  bar  two  small  6  9
# 8  bar  two  large  7  9

# %%
pd.pivot_table(df, values='D', index=['A', 'B'],
                    columns=['C'], aggfunc=np.sum, fill_value=0)

pd.pivot_table(df, values=['D', 'E'], index=['A', 'C'],
                    aggfunc={'D': np.mean,
                             'E': np.mean})

pd.pivot_table(df, values=['D', 'E'], index=['A', 'C'],
                    aggfunc={'D': np.mean,
                             'E': [min, max, np.mean]})
# Out:
#                   D    E
#                mean  max      mean  min
# A   C
# bar large  5.500000  9.0  7.500000  6.0
#     small  5.500000  9.0  8.500000  8.0
# foo large  2.000000  5.0  4.500000  4.0
#     small  2.333333  6.0  4.333333  2.0

# %%
def pounds_to_metric(pounds):
  kilograms = pounds / 2.2
  grams = kilograms * 1000
  return 'The amount you entered is equal to {} kilograms and {} grams.'.format(int(kilograms), grams)

# %%
# %timeit pounds_to_metric(115)
# Out:
# The slowest run took 14.62 times longer than the fastest. This could mean that an intermediate result is being cached.
# 1000000 loops, best of 5: 1.4 µs per loop

# %%
# %load_ext line_profiler
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-e874c3a3f342> in <module>()
# ----> 1 get_ipython().magic('load_ext line_profiler')
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in magic(self, arg_s)
#    2158         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2159         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2160         return self.run_line_magic(magic_name, magic_arg_s)
#    2161
#    2162     #-------------------------------------------------------------------------
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line)
#    2079                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2080             with self.builtin_trap:
# -> 2081                 result = fn(*args,**kwargs)
# ...

# %%
# %lprun -f pounds_to_metric pounds_to_metric(115)
# Out:
# UsageError: Line magic function `%lprun` not found.
